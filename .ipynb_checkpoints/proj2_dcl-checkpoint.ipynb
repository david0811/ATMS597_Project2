# %% [markdown]
# ## Accessing NOAA Climate Data Online

# %%
# Dependencies
import requests
import datetime
import pandas as pd
from IPython import display # For updating the cell dynamically
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})

# %%
"""
Adapted from from Stefanie Molin: Hands-On-Data-Analysis-With-Pandas. Available at:
https://github.com/stefmolin/Hands-On-Data-Analysis-with-Pandas/tree/master/ch_04
"""

def make_request(endpoint, payload=None):
    """
    Make a request to a specific endpoint on the weather API
    passing headers and optional payload.
    
    Parameters:
        - endpoint: The endpoint of the API you want to 
                    make a GET request to.
        - payload: A dictionary of data to pass along 
                   with the request.
    
    Returns:
        Response object.
    """
    return requests.get(
        f'https://www.ncdc.noaa.gov/cdo-web/api/v2/{endpoint}',
        headers={
            'token': 'DOENrJHGTEFUiebNMWZLniFJXUGTiVxr'
        },
        params=payload
    )

# %%
"""
Search for UK stations in the GHNCD dataset and show the results (json)
"""

make_request('stations', 
        {
            'datasetid' : 'GHCND', # Global Historical Climatology Network - Daily (GHCND) dataset
            'locationid' : 'FIPS:UK', # UK
            'datacategoryid' : 'TEMP', # Check for temperature data
            'limit' : 1000 # Return maximum allowed
        }).json()
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 143, 'limit': 1000}},
#  'results': [{'elevation': 78,
#    'mindate': '1880-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 52.42,
#    'name': 'CET CENTRAL ENGLAND, UK',
#    'datacoverage': 1,
#    'id': 'GHCND:UK000000000',
#    'elevationUnit': 'METERS',
#    'longitude': -1.83},
#   {'elevation': 82,
#    'mindate': '1929-10-01',
#    'maxdate': '2020-02-03',
#    'latitude': 60.1331,
#    'name': 'LERWICK, UK',
#    'datacoverage': 0.9895,
#    'id': 'GHCND:UK000003005',
#    'elevationUnit': 'METERS',
#    'longitude': -1.1831},
#   {'elevation': 9,
#    'mindate': '1873-07-01',
#    'maxdate': '2020-02-03',
#    'latitude': 58.33,
#    'name': 'STORNOWAY AIRPORT, UK',
#    'datacoverage': 0.9876,
#    'id': 'GHCND:UK000003026',
#    'elevationUnit': 'METERS',
#    'longitude': -6.32},
#   {'elevation': 242,
#    'mindate': '1931-01-01',
#    'maxdate': '2020-02-03',
#    'latitude': 55.3167,
#    'name': 'ESKDALEMUIR, UK',
#    'datacoverage': 0.9991,
#    'id': 'GHCND:UK000003162',
#    'elevationUnit': 'METERS',
#    'longitude': -3.2},
#   {'elevation': 11,
#    'mindate': '1930-12-01',
#    'maxdate': '2020-02-03',
#    'latitude': 53.25,
#    'name': 'VALLEY, UK',
#    'datacoverage': 0.9839,
#    'id': 'GHCND:UK000003302',
#    'elevationUnit': 'METERS',
#    'longitude': -4.5331},
#   {'elevation': 88,
#    'mindate': '1973-01-01',
#    'maxdate': '2020-02-03',
#    'latitude': 50.2167,
#    'name': 'CAMBORNE, UK',
#    'datacoverage': 0.8792,
#    'id': 'GHCND:UK000003808',
#    'elevationUnit': 'METERS',
#    'longitude': -5.3167},
#   {'elevation': 62,
#    'mindate': '1838-01-01',
#    'maxdate': '2017-12-31',
#    'latitude': 54.35,
#    'name': 'ARMAGH, UK',
#    'datacoverage': 0.9663,
#    'id': 'GHCND:UK000047811',
#    'elevationUnit': 'METERS',
#    'longitude': -6.65},
#   {'elevation': 63,
#    'mindate': '1814-12-31',
#    'maxdate': '2019-04-30',
#    'latitude': 51.7667,
#    'name': 'OXFORD, UK',
#    'datacoverage': 1,
#    'id': 'GHCND:UK000056225',
#    'elevationUnit': 'METERS',
#    'longitude': -1.2667},
#   {'elevation': 36,
#    'mindate': '1929-10-01',
#    'maxdate': '2020-02-03',
#    'latitude': 58.45,
#    'name': 'WICK, UK',
#    'datacoverage': 0.9804,
#    'id': 'GHCND:UK000070765',
#    'elevationUnit': 'METERS',
#    'longitude': -3.0831},
#   {'elevation': 145,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 51.5017,
#    'name': 'LYNEHAM, UK',
#    'datacoverage': 0.9993,
#    'id': 'GHCND:UKE00102158',
#    'elevationUnit': 'METERS',
#    'longitude': -1.9908},
#   {'elevation': 26,
#    'mindate': '2000-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 58.95,
#    'name': 'KIRKWALL, UK',
#    'datacoverage': 0.9908,
#    'id': 'GHCND:UKE00105630',
#    'elevationUnit': 'METERS',
#    'longitude': -2.9},
#   {'elevation': 5,
#    'mindate': '2000-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 57.65,
#    'name': 'KINLOSS, UK',
#    'datacoverage': 0.9995,
#    'id': 'GHCND:UKE00105636',
#    'elevationUnit': 'METERS',
#    'longitude': -3.57},
#   {'elevation': 13,
#    'mindate': '2000-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 52.1931,
#    'name': 'CAMBRIDGE B. GDNS, UK',
#    'datacoverage': 0.995,
#    'id': 'GHCND:UKE00105648',
#    'elevationUnit': 'METERS',
#    'longitude': 0.1317},
#   {'elevation': 32,
#    'mindate': '2000-12-31',
#    'maxdate': '2005-10-31',
#    'latitude': 53.92,
#    'name': 'ASKHAM BRYAN, UK',
#    'datacoverage': 0.9994,
#    'id': 'GHCND:UKE00105651',
#    'elevationUnit': 'METERS',
#    'longitude': -1.17},
#   {'elevation': 85,
#    'mindate': '2000-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 51.08,
#    'name': 'GOUDHURST, UK',
#    'datacoverage': 0.7358,
#    'id': 'GHCND:UKE00105657',
#    'elevationUnit': 'METERS',
#    'longitude': 0.46},
#   {'elevation': 32,
#    'mindate': '1914-01-01',
#    'maxdate': '2011-03-31',
#    'latitude': 55.85,
#    'name': 'PAISLEY, UK',
#    'datacoverage': 0.998,
#    'id': 'GHCND:UKE00105660',
#    'elevationUnit': 'METERS',
#    'longitude': -4.4297},
#   {'elevation': 301,
#    'mindate': '2000-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 52.35,
#    'name': 'CWMYSTWYTH, UK',
#    'datacoverage': 0.9219,
#    'id': 'GHCND:UKE00105669',
#    'elevationUnit': 'METERS',
#    'longitude': -3.82},
#   {'elevation': 51,
#    'mindate': '2000-12-31',
#    'maxdate': '2002-06-29',
#    'latitude': 51.43,
#    'name': 'LONG ASHTON, UK',
#    'datacoverage': 0.9982,
#    'id': 'GHCND:UKE00105675',
#    'elevationUnit': 'METERS',
#    'longitude': -2.67},
#   {'elevation': 81,
#    'mindate': '2000-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 54.65,
#    'name': 'ALDERGROVE, UK',
#    'datacoverage': 0.9996,
#    'id': 'GHCND:UKE00105681',
#    'elevationUnit': 'METERS',
#    'longitude': -6.22},
#   {'elevation': 48,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 55.4767,
#    'name': 'AUCHINCRUIVE, UK',
#    'datacoverage': 0.9106,
#    'id': 'GHCND:UKE00105856',
#    'elevationUnit': 'METERS',
#    'longitude': -4.5658},
#   {'elevation': 55,
#    'mindate': '1959-12-31',
#    'maxdate': '2013-10-11',
#    'latitude': 55.0989,
#    'name': 'GLENLEE, UK',
#    'datacoverage': 0.9828,
#    'id': 'GHCND:UKE00105857',
#    'elevationUnit': 'METERS',
#    'longitude': -4.1858},
#   {'elevation': 73,
#    'mindate': '1960-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 54.925,
#    'name': 'THREAVE, UK',
#    'datacoverage': 0.9731,
#    'id': 'GHCND:UKE00105858',
#    'elevationUnit': 'METERS',
#    'longitude': -3.95},
#   {'elevation': 169,
#    'mindate': '1906-01-01',
#    'maxdate': '2017-12-31',
#    'latitude': 54.67,
#    'name': 'NEWTON RIGG, UK',
#    'datacoverage': 0.7827,
#    'id': 'GHCND:UKE00105860',
#    'elevationUnit': 'METERS',
#    'longitude': -2.7858},
#   {'elevation': 91,
#    'mindate': '1960-01-17',
#    'maxdate': '2007-04-30',
#    'latitude': 54.3381,
#    'name': 'GRIZEDALE, UK',
#    'datacoverage': 0.9759,
#    'id': 'GHCND:UKE00105861',
#    'elevationUnit': 'METERS',
#    'longitude': -3.02},
#   {'elevation': 33,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 53.7739,
#    'name': 'PRESTON MOOR PARK, UK',
#    'datacoverage': 0.9293,
#    'id': 'GHCND:UKE00105862',
#    'elevationUnit': 'METERS',
#    'longitude': -2.7031},
#   {'elevation': 5,
#    'mindate': '1920-12-31',
#    'maxdate': '2004-12-31',
#    'latitude': 53.2167,
#    'name': 'HAWARDEN BRIDGE, UK',
#    'datacoverage': 0.6956,
#    'id': 'GHCND:UKE00105863',
#    'elevationUnit': 'METERS',
#    'longitude': -3.0281},
#   {'elevation': 210,
#    'mindate': '1960-11-30',
#    'maxdate': '2004-12-31',
#    'latitude': 53.15,
#    'name': 'LOGGERHEADS COLOMENDY CENTRE, UK',
#    'datacoverage': 0.998,
#    'id': 'GHCND:UKE00105864',
#    'elevationUnit': 'METERS',
#    'longitude': -3.1958},
#   {'elevation': 4,
#    'mindate': '1959-12-31',
#    'maxdate': '2013-01-31',
#    'latitude': 57.4867,
#    'name': 'INVERNESS, UK',
#    'datacoverage': 0.9786,
#    'id': 'GHCND:UKE00105865',
#    'elevationUnit': 'METERS',
#    'longitude': -4.2231},
#   {'elevation': 133,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 52.1389,
#    'name': 'ABERPORTH, UK',
#    'datacoverage': 0.9998,
#    'id': 'GHCND:UKE00105866',
#    'elevationUnit': 'METERS',
#    'longitude': -4.5717},
#   {'elevation': 31,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 52.4317,
#    'name': 'GOGERDDAN, UK',
#    'datacoverage': 0.9941,
#    'id': 'GHCND:UKE00105867',
#    'elevationUnit': 'METERS',
#    'longitude': -4.0197},
#   {'elevation': 10,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 50.6139,
#    'name': 'SWANAGE, UK',
#    'datacoverage': 0.9801,
#    'id': 'GHCND:UKE00105869',
#    'elevationUnit': 'METERS',
#    'longitude': -1.9581},
#   {'elevation': 50,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 50.3539,
#    'name': 'PLYMOUTH MOUNTBATTEN, UK',
#    'datacoverage': 0.9933,
#    'id': 'GHCND:UKE00105870',
#    'elevationUnit': 'METERS',
#    'longitude': -4.1208},
#   {'elevation': 32,
#    'mindate': '1960-04-30',
#    'maxdate': '2017-12-31',
#    'latitude': 50.2917,
#    'name': 'SLAPTON, UK',
#    'datacoverage': 0.9973,
#    'id': 'GHCND:UKE00105871',
#    'elevationUnit': 'METERS',
#    'longitude': -3.6508},
#   {'elevation': 103,
#    'mindate': '1959-12-31',
#    'maxdate': '2008-11-30',
#    'latitude': 50.4367,
#    'name': 'ST MAWGAN, UK',
#    'datacoverage': 0.9999,
#    'id': 'GHCND:UKE00105872',
#    'elevationUnit': 'METERS',
#    'longitude': -4.9989},
#   {'elevation': 15,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 50.8281,
#    'name': 'BUDE, UK',
#    'datacoverage': 1,
#    'id': 'GHCND:UKE00105873',
#    'elevationUnit': 'METERS',
#    'longitude': -4.5458},
#   {'elevation': 339,
#    'mindate': '1959-12-31',
#    'maxdate': '2005-05-01',
#    'latitude': 57.0058,
#    'name': 'BRAEMAR, UK',
#    'datacoverage': 0.9956,
#    'id': 'GHCND:UKE00105874',
#    'elevationUnit': 'METERS',
#    'longitude': -3.3967},
#   {'elevation': 283,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 57.0367,
#    'name': 'BALMORAL, UK',
#    'datacoverage': 0.9987,
#    'id': 'GHCND:UKE00105875',
#    'elevationUnit': 'METERS',
#    'longitude': -3.22},
#   {'elevation': 116,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-11-28',
#    'latitude': 54.4517,
#    'name': 'HILLSBOROUGH, UK',
#    'datacoverage': 0.9071,
#    'id': 'GHCND:UKE00105876',
#    'elevationUnit': 'METERS',
#    'longitude': -6.07},
#   {'elevation': 56,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 54.6031,
#    'name': 'STORMONT CASTLE, UK',
#    'datacoverage': 0.9833,
#    'id': 'GHCND:UKE00105877',
#    'elevationUnit': 'METERS',
#    'longitude': -5.8289},
#   {'elevation': 126,
#    'mindate': '1961-08-01',
#    'maxdate': '2017-12-31',
#    'latitude': 54.4389,
#    'name': 'LOUGH NAVAR FOREST, UK',
#    'datacoverage': 0.9906,
#    'id': 'GHCND:UKE00105878',
#    'elevationUnit': 'METERS',
#    'longitude': -7.9031},
#   {'elevation': 65,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 57.205,
#    'name': 'DYCE, UK',
#    'datacoverage': 0.9999,
#    'id': 'GHCND:UKE00105881',
#    'elevationUnit': 'METERS',
#    'longitude': -2.2039},
#   {'elevation': 345,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 53.0608,
#    'name': 'ALWEN, UK',
#    'datacoverage': 0.9807,
#    'id': 'GHCND:UKE00105882',
#    'elevationUnit': 'METERS',
#    'longitude': -3.5539},
#   {'elevation': 130,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 56.5289,
#    'name': 'ARDTALNAIG, UK',
#    'datacoverage': 0.9847,
#    'id': 'GHCND:UKE00105884',
#    'elevationUnit': 'METERS',
#    'longitude': -4.1108},
#   {'elevation': 94,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-19',
#    'latitude': 56.7181,
#    'name': 'FASKALLY, UK',
#    'datacoverage': 0.9092,
#    'id': 'GHCND:UKE00105885',
#    'elevationUnit': 'METERS',
#    'longitude': -3.7689},
#   {'elevation': 10,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 56.3767,
#    'name': 'LEUCHARS, UK',
#    'datacoverage': 1,
#    'id': 'GHCND:UKE00105886',
#    'elevationUnit': 'METERS',
#    'longitude': -2.8617},
#   {'elevation': 185,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 55.8239,
#    'name': 'PENICUIK, UK',
#    'datacoverage': 0.9822,
#    'id': 'GHCND:UKE00105887',
#    'elevationUnit': 'METERS',
#    'longitude': -3.2258},
#   {'elevation': 26,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 55.9667,
#    'name': 'EDINBURGH ROYAL BOTANIC GARDE, UK',
#    'datacoverage': 0.9995,
#    'id': 'GHCND:UKE00105888',
#    'elevationUnit': 'METERS',
#    'longitude': -3.21},
#   {'elevation': 23,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 56.0039,
#    'name': 'DUNBAR, UK',
#    'datacoverage': 0.9835,
#    'id': 'GHCND:UKE00105889',
#    'elevationUnit': 'METERS',
#    'longitude': -2.5258},
#   {'elevation': 253,
#    'mindate': '1959-12-31',
#    'maxdate': '2006-04-10',
#    'latitude': 55.7031,
#    'name': 'BLYTH BRIDGE, UK',
#    'datacoverage': 0.9997,
#    'id': 'GHCND:UKE00105890',
#    'elevationUnit': 'METERS',
#    'longitude': -3.3667},
#   {'elevation': 168,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 55.5408,
#    'name': 'BOWHILL, UK',
#    'datacoverage': 0.9997,
#    'id': 'GHCND:UKE00105891',
#    'elevationUnit': 'METERS',
#    'longitude': -2.905},
#   {'elevation': 201,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 55.2339,
#    'name': 'KIELDER CASTLE, UK',
#    'datacoverage': 0.9655,
#    'id': 'GHCND:UKE00105892',
#    'elevationUnit': 'METERS',
#    'longitude': -2.5789},
#   {'elevation': 95,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 55.215,
#    'name': 'MORPETH COCKLE PARK, UK',
#    'datacoverage': 0.9941,
#    'id': 'GHCND:UKE00105893',
#    'elevationUnit': 'METERS',
#    'longitude': -1.6858},
#   {'elevation': 6,
#    'mindate': '1903-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 53.1467,
#    'name': 'SKEGNESS, UK',
#    'datacoverage': 0.9833,
#    'id': 'GHCND:UKE00105895',
#    'elevationUnit': 'METERS',
#    'longitude': 0.3489},
#   {'elevation': 7,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-14',
#    'latitude': 51.9589,
#    'name': 'EAST BERGHOLT, UK',
#    'datacoverage': 0.971,
#    'id': 'GHCND:UKE00105897',
#    'elevationUnit': 'METERS',
#    'longitude': 1.0267},
#   {'elevation': 89,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 52.1231,
#    'name': 'WATTISHAM, UK',
#    'datacoverage': 0.9784,
#    'id': 'GHCND:UKE00105898',
#    'elevationUnit': 'METERS',
#    'longitude': 0.9617},
#   {'elevation': 25,
#    'mindate': '1889-01-01',
#    'maxdate': '2004-12-31',
#    'latitude': 52.4889,
#    'name': 'LOWESTOFT, UK',
#    'datacoverage': 0.8885,
#    'id': 'GHCND:UKE00105899',
#    'elevationUnit': 'METERS',
#    'longitude': 1.75},
#   {'elevation': 128,
#    'mindate': '1916-01-01',
#    'maxdate': '2017-12-31',
#    'latitude': 51.8067,
#    'name': 'ROTHAMSTED, UK',
#    'datacoverage': 0.9989,
#    'id': 'GHCND:UKE00105900',
#    'elevationUnit': 'METERS',
#    'longitude': 0.3581},
#   {'elevation': 32,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 51.7317,
#    'name': 'WRITTLE, UK',
#    'datacoverage': 0.9827,
#    'id': 'GHCND:UKE00105901',
#    'elevationUnit': 'METERS',
#    'longitude': 0.4308},
#   {'elevation': 381,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 54.1,
#    'name': 'MALHAM TARN, UK',
#    'datacoverage': 0.9868,
#    'id': 'GHCND:UKE00105902',
#    'elevationUnit': 'METERS',
#    'longitude': -2.1617},
#   {'elevation': 134,
#    'mindate': '1910-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 53.8131,
#    'name': 'BRADFORD, UK',
#    'datacoverage': 0.9917,
#    'id': 'GHCND:UKE00105903',
#    'elevationUnit': 'METERS',
#    'longitude': -1.7739},
#   {'elevation': 131,
#    'mindate': '1882-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 53.3808,
#    'name': 'SHEFFIELD, UK',
#    'datacoverage': 0.9839,
#    'id': 'GHCND:UKE00105904',
#    'elevationUnit': 'METERS',
#    'longitude': -1.49},
#   {'elevation': 307,
#    'mindate': '1874-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 53.2567,
#    'name': 'BUXTON, UK',
#    'datacoverage': 0.7175,
#    'id': 'GHCND:UKE00105905',
#    'elevationUnit': 'METERS',
#    'longitude': -1.9131},
#   {'elevation': 117,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 53.005,
#    'name': 'NOTTINGHAM WATNALL, UK',
#    'datacoverage': 0.9971,
#    'id': 'GHCND:UKE00105906',
#    'elevationUnit': 'METERS',
#    'longitude': -1.25},
#   {'elevation': 46,
#    'mindate': '1959-12-31',
#    'maxdate': '2009-06-30',
#    'latitude': 53.2231,
#    'name': 'WARSOP, UK',
#    'datacoverage': 0.9728,
#    'id': 'GHCND:UKE00105907',
#    'elevationUnit': 'METERS',
#    'longitude': -1.115},
#   {'elevation': 119,
#    'mindate': '1959-12-31',
#    'maxdate': '2004-12-31',
#    'latitude': 52.68,
#    'name': 'NEWTOWN LINFORD, UK',
#    'datacoverage': 0.9777,
#    'id': 'GHCND:UKE00105908',
#    'elevationUnit': 'METERS',
#    'longitude': -1.2158},
#   {'elevation': 47,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 52.2058,
#    'name': 'WELLESBOURNE, UK',
#    'datacoverage': 0.9798,
#    'id': 'GHCND:UKE00105909',
#    'elevationUnit': 'METERS',
#    'longitude': -1.6031},
#   {'elevation': 179,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 52.9981,
#    'name': 'KEELE, UK',
#    'datacoverage': 0.9923,
#    'id': 'GHCND:UKE00105910',
#    'elevationUnit': 'METERS',
#    'longitude': -2.27},
#   {'elevation': 62,
#    'mindate': '1899-12-31',
#    'maxdate': '2008-10-31',
#    'latitude': 52.1117,
#    'name': 'MALVERN, UK',
#    'datacoverage': 0.9803,
#    'id': 'GHCND:UKE00105911',
#    'elevationUnit': 'METERS',
#    'longitude': -2.3067},
#   {'elevation': 153,
#    'mindate': '1959-12-31',
#    'maxdate': '2004-10-31',
#    'latitude': 52.4367,
#    'name': 'HALESOWEN, UK',
#    'datacoverage': 0.9997,
#    'id': 'GHCND:UKE00105912',
#    'elevationUnit': 'METERS',
#    'longitude': -2.075},
#   {'elevation': 25,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 57.6131,
#    'name': 'KINLOCHEWE, UK',
#    'datacoverage': 0.9613,
#    'id': 'GHCND:UKE00105913',
#    'elevationUnit': 'METERS',
#    'longitude': -5.31},
#   {'elevation': 155,
#    'mindate': '1959-12-31',
#    'maxdate': '2014-11-30',
#    'latitude': 52.2117,
#    'name': 'LYONSHALL, UK',
#    'datacoverage': 0.9919,
#    'id': 'GHCND:UKE00105914',
#    'elevationUnit': 'METERS',
#    'longitude': -2.9681},
#   {'elevation': 137,
#    'mindate': '1959-12-31',
#    'maxdate': '2016-07-17',
#    'latitude': 51.5608,
#    'name': 'HAMPSTEAD, UK',
#    'datacoverage': 0.9902,
#    'id': 'GHCND:UKE00105915',
#    'elevationUnit': 'METERS',
#    'longitude': 0.1789},
#   {'elevation': 56,
#    'mindate': '1959-12-31',
#    'maxdate': '2006-03-31',
#    'latitude': 51.185,
#    'name': 'WYE, UK',
#    'datacoverage': 0.9977,
#    'id': 'GHCND:UKE00105917',
#    'elevationUnit': 'METERS',
#    'longitude': 0.9481},
#   {'elevation': 49,
#    'mindate': '1960-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 51.3458,
#    'name': 'MANSTON, UK',
#    'datacoverage': 0.9991,
#    'id': 'GHCND:UKE00105918',
#    'elevationUnit': 'METERS',
#    'longitude': 1.34},
#   {'elevation': 45,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 50.855,
#    'name': 'HASTINGS, UK',
#    'datacoverage': 0.9996,
#    'id': 'GHCND:UKE00105921',
#    'elevationUnit': 'METERS',
#    'longitude': 0.5717},
#   {'elevation': 48,
#    'mindate': '1960-03-31',
#    'maxdate': '2017-12-30',
#    'latitude': 51.6031,
#    'name': 'WALLINGFORD, UK',
#    'datacoverage': 0.9822,
#    'id': 'GHCND:UKE00105922',
#    'elevationUnit': 'METERS',
#    'longitude': -1.1081},
#   {'elevation': 10,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 50.7789,
#    'name': 'HURN, UK',
#    'datacoverage': 0.9999,
#    'id': 'GHCND:UKE00105923',
#    'elevationUnit': 'METERS',
#    'longitude': -1.8339},
#   {'elevation': 16,
#    'mindate': '1959-12-31',
#    'maxdate': '2003-09-30',
#    'latitude': 50.7417,
#    'name': 'EVERTON, UK',
#    'datacoverage': 0.9986,
#    'id': 'GHCND:UKE00105924',
#    'elevationUnit': 'METERS',
#    'longitude': -1.5739},
#   {'elevation': 117,
#    'mindate': '1959-12-31',
#    'maxdate': '2012-12-31',
#    'latitude': 51.1231,
#    'name': 'LECKFORD, UK',
#    'datacoverage': 0.9982,
#    'id': 'GHCND:UKE00105925',
#    'elevationUnit': 'METERS',
#    'longitude': -1.4381},
#   {'elevation': 115,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 51.1767,
#    'name': 'ALICE HOLT LODGE, UK',
#    'datacoverage': 0.9993,
#    'id': 'GHCND:UKE00105927',
#    'elevationUnit': 'METERS',
#    'longitude': 0.8481},
#   {'elevation': 5,
#    'mindate': '1959-12-31',
#    'maxdate': '2009-11-13',
#    'latitude': 57.0139,
#    'name': 'RHUM KINLOCH, UK',
#    'datacoverage': 0.8481,
#    'id': 'GHCND:UKE00105929',
#    'elevationUnit': 'METERS',
#    'longitude': -6.2867},
#   {'elevation': 12,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 56.0281,
#    'name': 'BENMORE YOUNGER BOTANIC GARDE, UK',
#    'datacoverage': 0.9989,
#    'id': 'GHCND:UKE00105930',
#    'elevationUnit': 'METERS',
#    'longitude': -4.9858},
#   {'elevation': 43,
#    'mindate': '1959-12-31',
#    'maxdate': '2012-12-31',
#    'latitude': 55.8389,
#    'name': 'BUTE ROTHESAY, UK',
#    'datacoverage': 0.9945,
#    'id': 'GHCND:UKE00105931',
#    'elevationUnit': 'METERS',
#    'longitude': -5.0639},
#   {'elevation': 393,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 55.4167,
#    'name': 'LEADHILLS, UK',
#    'datacoverage': 0.9813,
#    'id': 'GHCND:UKE00105932',
#    'elevationUnit': 'METERS',
#    'longitude': -3.7589},
#   {'elevation': 208,
#    'mindate': '1959-12-31',
#    'maxdate': '2006-10-31',
#    'latitude': 55.7,
#    'name': 'CARNWATH, UK',
#    'datacoverage': 0.9991,
#    'id': 'GHCND:UKE00105933',
#    'elevationUnit': 'METERS',
#    'longitude': -3.6331},
#   {'elevation': 9,
#    'mindate': '1959-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 56.4967,
#    'name': 'TIREE, UK',
#    'datacoverage': 0.9819,
#    'id': 'GHCND:UKE00107640',
#    'elevationUnit': 'METERS',
#    'longitude': -6.8867},
#   {'elevation': 20,
#    'mindate': '1964-08-31',
#    'maxdate': '2017-12-31',
#    'latitude': 51.0058,
#    'name': 'YEOVILTON, UK',
#    'datacoverage': 0.9806,
#    'id': 'GHCND:UKE00107962',
#    'elevationUnit': 'METERS',
#    'longitude': -2.64},
#   {'elevation': 2,
#    'mindate': '1959-12-31',
#    'maxdate': '2007-07-31',
#    'latitude': 52.745,
#    'name': 'TERRINGTON ST CLEMENT, UK',
#    'datacoverage': 0.9999,
#    'id': 'GHCND:UKE00108855',
#    'elevationUnit': 'METERS',
#    'longitude': 0.29},
#   {'elevation': 327,
#    'mindate': '2005-06-27',
#    'maxdate': '2017-12-31',
#    'latitude': 57.0108,
#    'name': 'BRAEMAR 1, UK',
#    'datacoverage': 0.9956,
#    'id': 'GHCND:UKE00115807',
#    'elevationUnit': 'METERS',
#    'longitude': -3.3958},
#   {'elevation': 18,
#    'mindate': '2004-12-31',
#    'maxdate': '2010-10-31',
#    'latitude': 52.4831,
#    'name': 'LOWESTOFT MONKTON AVENUE, UK',
#    'datacoverage': 0.9887,
#    'id': 'GHCND:UKE00115811',
#    'elevationUnit': 'METERS',
#    'longitude': 1.7308},
#   {'elevation': 10,
#    'mindate': '2012-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 53.7742,
#    'name': 'BLACKPOOL SQUIRES GATE, UK',
#    'datacoverage': 0.9995,
#    'id': 'GHCND:UKE00156832',
#    'elevationUnit': 'METERS',
#    'longitude': -3.0381},
#   {'elevation': 126,
#    'mindate': '2012-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 51.1614,
#    'name': 'BOSCOMBE DOWN, UK',
#    'datacoverage': 0.9995,
#    'id': 'GHCND:UKE00156836',
#    'elevationUnit': 'METERS',
#    'longitude': -1.7531},
#   {'elevation': 28,
#    'mindate': '2012-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 54.9342,
#    'name': 'CARLISLE, UK',
#    'datacoverage': 0.9995,
#    'id': 'GHCND:UKE00156840',
#    'elevationUnit': 'METERS',
#    'longitude': -2.9619},
#   {'elevation': 6,
#    'mindate': '2012-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 53.8275,
#    'name': 'CAWOOD, UK',
#    'datacoverage': 0.9995,
#    'id': 'GHCND:UKE00156844',
#    'elevationUnit': 'METERS',
#    'longitude': -1.1467},
#   {'elevation': 102,
#    'mindate': '1879-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 54.7678,
#    'name': 'DURHAM, UK',
#    'datacoverage': 0.9874,
#    'id': 'GHCND:UKE00156852',
#    'elevationUnit': 'METERS',
#    'longitude': -1.5842},
#   {'elevation': 49,
#    'mindate': '2012-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 51.4306,
#    'name': 'LACOCK, UK',
#    'datacoverage': 0.9831,
#    'id': 'GHCND:UKE00156856',
#    'elevationUnit': 'METERS',
#    'longitude': -2.1131},
#   {'elevation': 7,
#    'mindate': '2012-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 57.7117,
#    'name': 'LOSSIEMOUTH, UK',
#    'datacoverage': 0.9995,
#    'id': 'GHCND:UKE00156860',
#    'elevationUnit': 'METERS',
#    'longitude': -3.3217},
#   {'elevation': 41,
#    'mindate': '2012-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 52.4008,
#    'name': 'MONKS WOOD, UK',
#    'datacoverage': 0.9946,
#    'id': 'GHCND:UKE00156864',
#    'elevationUnit': 'METERS',
#    'longitude': 0.2353},
#   {'elevation': 7,
#    'mindate': '2012-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 54.0758,
#    'name': 'MORECAMBE NUMBER 2, UK',
#    'datacoverage': 0.9825,
#    'id': 'GHCND:UKE00156868',
#    'elevationUnit': 'METERS',
#    'longitude': -2.8581},
#   {'elevation': 37,
#    'mindate': '2012-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 52.0994,
#    'name': 'PERSHORE COLLEGE, UK',
#    'datacoverage': 0.9995,
#    'id': 'GHCND:UKE00156872',
#    'elevationUnit': 'METERS',
#    'longitude': -2.0583},
#   {'elevation': 43,
#    'mindate': '2012-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 52.8358,
#    'name': 'SUTTON BONINGTON, UK',
#    'datacoverage': 0.9995,
#    'id': 'GHCND:UKE00156876',
#    'elevationUnit': 'METERS',
#    'longitude': -1.2494},
#   {'elevation': 20,
#    'mindate': '2013-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 50.575,
#    'name': 'WIGHT ST CATHERINES POINT, UK',
#    'datacoverage': 0.9993,
#    'id': 'GHCND:UKE00156880',
#    'elevationUnit': 'METERS',
#    'longitude': -1.2956},
#   {'elevation': 38,
#    'mindate': '1904-02-01',
#    'maxdate': '2017-12-31',
#    'latitude': 51.3103,
#    'name': 'WISLEY, UK',
#    'datacoverage': 0.9488,
#    'id': 'GHCND:UKE00156884',
#    'elevationUnit': 'METERS',
#    'longitude': 0.4744},
#   {'elevation': 89,
#    'mindate': '2013-12-31',
#    'maxdate': '2017-12-31',
#    'latitude': 52.0142,
#    'name': 'WOBURN, UK',
#    'datacoverage': 0.9993,
#    'id': 'GHCND:UKE00156888',
#    'elevationUnit': 'METERS',
#    'longitude': 0.5942},
#   {'elevation': 13,
#    'mindate': '1984-08-01',
#    'maxdate': '2016-04-25',
#    'latitude': 60.117,
#    'name': 'FOULA NUMBER 2, UK',
#    'datacoverage': 0.8264,
#    'id': 'GHCND:UKM00003014',
#    'elevationUnit': 'METERS',
#    'longitude': -2.067},
#   {'elevation': 15.5,
#    'mindate': '1973-01-01',
#    'maxdate': '2020-02-03',
#    'latitude': 58.958,
#    'name': 'KIRKWALL, UK',
#    'datacoverage': 0.9977,
#    'id': 'GHCND:UKM00003017',
#    'elevationUnit': 'METERS',
#    'longitude': -2.905},
#   {'elevation': 6.7,
#    'mindate': '1973-01-01',
#    'maxdate': '2020-02-03',
#    'latitude': 57.649,
#    'name': 'KINLOSS, UK',
#    'datacoverage': 0.9976,
#    'id': 'GHCND:UKM00003066',
#    'elevationUnit': 'METERS',
#    'longitude': -3.561},
#   {'elevation': 102,
#    'mindate': '1929-10-02',
#    'maxdate': '2020-02-03',
#    'latitude': 57.18,
#    'name': 'CRAIBSTONE, UK',
#    'datacoverage': 0.5894,
#    'id': 'GHCND:UKM00003091',
#    'elevationUnit': 'METERS',
#    'longitude': -2.2},
#   {'elevation': 11.6,
#    'mindate': '1937-03-01',
#    'maxdate': '2020-02-03',
#    'latitude': 56.499,
#    'name': 'TIREE, UK',
#    'datacoverage': 0.5836,
#    'id': 'GHCND:UKM00003100',
#    'elevationUnit': 'METERS',
#    'longitude': -6.869},
#   {'elevation': 11.6,
#    'mindate': '1973-01-01',
#    'maxdate': '2020-02-03',
#    'latitude': 56.373,
#    'name': 'LEUCHARS, UK',
#    'datacoverage': 0.9976,
#    'id': 'GHCND:UKM00003171',
#    'elevationUnit': 'METERS',
#    'longitude': -2.868},
#   {'elevation': 40,
#    'mindate': '1973-01-01',
#    'maxdate': '2020-02-03',
#    'latitude': 54.3,
#    'name': 'LEEMING, UK',
#    'datacoverage': 0.9977,
#    'id': 'GHCND:UKM00003257',
#    'elevationUnit': 'METERS',
#    'longitude': -1.53},
#   {'elevation': 69,
#    'mindate': '1973-01-01',
#    'maxdate': '2020-02-03',
#    'latitude': 53.35,
#    'name': 'RINGWAY, UK',
#    'datacoverage': 0.9979,
#    'id': 'GHCND:UKM00003334',
#    'elevationUnit': 'METERS',
#    'longitude': -2.28},
#   {'elevation': 72,
#    'mindate': '1973-01-01',
#    'maxdate': '2020-02-03',
#    'latitude': 52.8,
#    'name': 'SHAWBURY, UK',
#    'datacoverage': 0.9975,
#    'id': 'GHCND:UKM00003414',
#    'elevationUnit': 'METERS',
#    'longitude': -2.67},
#   {'elevation': 134,
#    'mindate': '1973-01-01',
#    'maxdate': '2020-02-03',
#    'latitude': 52.133,
#    'name': 'ABERPORTH, UK',
#    'datacoverage': 0.997,
#    'id': 'GHCND:UKM00003502',
#    'elevationUnit': 'METERS',
#    'longitude': -4.567},
#   {'elevation': 86.6,
#    'mindate': '1973-01-01',
#    'maxdate': '2020-02-03',
#    'latitude': 52.127,
#    'name': 'WATTISHAM, UK',
#    'datacoverage': 0.9848,
#    'id': 'GHCND:UKM00003590',
#    'elevationUnit': 'METERS',
#    'longitude': 0.956},
#   {'elevation': 156.4,
#    'mindate': '1973-01-01',
#    'maxdate': '2020-02-03',
#    'latitude': 51.505,
#    'name': 'LYNEHAM, UK',
#    'datacoverage': 0.9951,
#    'id': 'GHCND:UKM00003740',
#    'elevationUnit': 'METERS',
#    'longitude': -1.993},
#   {'elevation': 25.3,
#    'mindate': '1948-12-01',
#    'maxdate': '2020-02-03',
#    'latitude': 51.478,
#    'name': 'HEATHROW, UK',
#    'datacoverage': 0.802,
#    'id': 'GHCND:UKM00003772',
#    'elevationUnit': 'METERS',
#    'longitude': -0.461},
#   {'elevation': 11.6,
#    'mindate': '1973-01-01',
#    'maxdate': '2020-02-03',
#    'latitude': 50.78,
#    'name': 'BOURNEMOUTH, UK',
#    'datacoverage': 0.9963,
#    'id': 'GHCND:UKM00003862',
#    'elevationUnit': 'METERS',
#    'longitude': -1.843},
#   {'elevation': 81.7,
#    'mindate': '1939-08-08',
#    'maxdate': '2020-02-03',
#    'latitude': 54.658,
#    'name': 'ALDERGROVE, UK',
#    'datacoverage': 0.5837,
#    'id': 'GHCND:UKM00003917',
#    'elevationUnit': 'METERS',
#    'longitude': -6.216},
#   {'elevation': 74.1,
#    'mindate': '1954-03-01',
#    'maxdate': '1957-05-31',
#    'latitude': 52.38333,
#    'name': 'MOLESWORTH, UK',
#    'datacoverage': 0.9924,
#    'id': 'GHCND:UKW00015014',
#    'elevationUnit': 'METERS',
#    'longitude': -0.41667},
#   {'elevation': 92,
#    'mindate': '1956-06-01',
#    'maxdate': '1964-02-29',
#    'latitude': 52.3,
#    'name': 'CHELVESTON, UK',
#    'datacoverage': 0.8866,
#    'id': 'GHCND:UKW00015015',
#    'elevationUnit': 'METERS',
#    'longitude': -0.53333},
#   {'elevation': 30.2,
#    'mindate': '1950-11-01',
#    'maxdate': '1951-10-25',
#    'latitude': 52.1,
#    'name': 'BASSINGBOURN, UK',
#    'datacoverage': 0.9916,
#    'id': 'GHCND:UKW00015018',
#    'elevationUnit': 'METERS',
#    'longitude': -0.05},
#   {'elevation': 27.1,
#    'mindate': '1946-01-20',
#    'maxdate': '1959-04-30',
#    'latitude': 53.38333,
#    'name': 'WARRINGTON, UK',
#    'datacoverage': 0.7773,
#    'id': 'GHCND:UKW00015027',
#    'elevationUnit': 'METERS',
#    'longitude': -2.65},
#   {'elevation': 49.1,
#    'mindate': '1955-09-09',
#    'maxdate': '1967-12-31',
#    'latitude': 52.36667,
#    'name': 'HUNTINGTON, UK',
#    'datacoverage': 0.9053,
#    'id': 'GHCND:UKW00015033',
#    'elevationUnit': 'METERS',
#    'longitude': -0.21667},
#   {'elevation': 40.2,
#    'mindate': '1950-10-03',
#    'maxdate': '1951-12-30',
#    'latitude': 52.35,
#    'name': 'WYTON, UK',
#    'datacoverage': 1,
#    'id': 'GHCND:UKW00015034',
#    'elevationUnit': 'METERS',
#    'longitude': -0.11667},
#   {'elevation': 72.2,
#    'mindate': '1950-09-26',
#    'maxdate': '1951-03-22',
#    'latitude': 53.16667,
#    'name': 'WADDINGTON, UK',
#    'datacoverage': 1,
#    'id': 'GHCND:UKW00015035',
#    'elevationUnit': 'METERS',
#    'longitude': -0.51667},
#   {'elevation': 91.1,
#    'mindate': '1951-08-01',
#    'maxdate': '1965-04-03',
#    'latitude': 51.75,
#    'name': 'OXFORD, UK',
#    'datacoverage': 0.9383,
#    'id': 'GHCND:UKW00015036',
#    'elevationUnit': 'METERS',
#    'longitude': -1.58333},
#   {'elevation': 133.2,
#    'mindate': '1951-11-01',
#    'maxdate': '1967-12-31',
#    'latitude': 51.93333,
#    'name': 'UPPER HEYFORD, UK',
#    'datacoverage': 0.9309,
#    'id': 'GHCND:UKW00015037',
#    'elevationUnit': 'METERS',
#    'longitude': -1.25},
#   {'elevation': 91.1,
#    'mindate': '1952-06-10',
#    'maxdate': '1964-06-03',
#    'latitude': 51.68333,
#    'name': 'FAIRFORD, UK',
#    'datacoverage': 0.9283,
#    'id': 'GHCND:UKW00015038',
#    'elevationUnit': 'METERS',
#    'longitude': -1.78333},
#   {'elevation': 125.3,
#    'mindate': '1954-01-26',
#    'maxdate': '1967-04-08',
#    'latitude': 51.38333,
#    'name': 'GREENHAM, UK',
#    'datacoverage': 0.7229,
#    'id': 'GHCND:UKW00015040',
#    'elevationUnit': 'METERS',
#    'longitude': -1.28333},
#   {'elevation': 21,
#    'mindate': '1954-10-01',
#    'maxdate': '1957-06-13',
#    'latitude': 53.36667,
#    'name': 'STURGATE, UK',
#    'datacoverage': 0.8723,
#    'id': 'GHCND:UKW00015041',
#    'elevationUnit': 'METERS',
#    'longitude': -0.68333},
#   {'elevation': 151.2,
#    'mindate': '1957-07-01',
#    'maxdate': '1962-08-24',
#    'latitude': 52.46667,
#    'name': 'BRUNTINGTHORPE, UK',
#    'datacoverage': 0.9261,
#    'id': 'GHCND:UKW00015042',
#    'elevationUnit': 'METERS',
#    'longitude': -1.11667},
#   {'elevation': 10.1,
#    'mindate': '1949-05-01',
#    'maxdate': '1967-12-31',
#    'latitude': 52.4,
#    'name': 'LAKENHEATH RAF, UK',
#    'datacoverage': 0.9743,
#    'id': 'GHCND:UKW00035034',
#    'elevationUnit': 'METERS',
#    'longitude': 0.56667},
#   {'elevation': 27.1,
#    'mindate': '1949-04-01',
#    'maxdate': '1951-01-18',
#    'latitude': 52.65,
#    'name': 'MARHAM, UK',
#    'datacoverage': 0.8602,
#    'id': 'GHCND:UKW00035035',
#    'elevationUnit': 'METERS',
#    'longitude': 0.55},
#   {'elevation': 68.3,
#    'mindate': '1949-06-01',
#    'maxdate': '1964-03-31',
#    'latitude': 52.85,
#    'name': 'SCULTHORPE ENGLAND, UK',
#    'datacoverage': 0.9498,
#    'id': 'GHCND:UKW00035036',
#    'elevationUnit': 'METERS',
#    'longitude': 0.76667},
#   {'elevation': 10.1,
#    'mindate': '1950-07-14',
#    'maxdate': '1967-12-31',
#    'latitude': 52.36667,
#    'name': 'MILDENHALL, UK',
#    'datacoverage': 0.8969,
#    'id': 'GHCND:UKW00035046',
#    'elevationUnit': 'METERS',
#    'longitude': 0.48333},
#   {'elevation': 44.2,
#    'mindate': '1935-10-27',
#    'maxdate': '2020-02-03',
#    'latitude': 51.35,
#    'name': 'MANSTON, UK',
#    'datacoverage': 0.5433,
#    'id': 'GHCND:UKW00035047',
#    'elevationUnit': 'METERS',
#    'longitude': 1.36667},
#   {'elevation': 26.2,
#    'mindate': '1951-06-06',
#    'maxdate': '1967-12-31',
#    'latitude': 52.13333,
#    'name': 'BENTWATERS, UK',
#    'datacoverage': 0.9298,
#    'id': 'GHCND:UKW00035048',
#    'elevationUnit': 'METERS',
#    'longitude': 1.43333},
#   {'elevation': 61.3,
#    'mindate': '1951-07-13',
#    'maxdate': '1959-01-09',
#    'latitude': 52.31667,
#    'name': 'STANTON, UK',
#    'datacoverage': 0.8623,
#    'id': 'GHCND:UKW00035049',
#    'elevationUnit': 'METERS',
#    'longitude': 0.91667},
#   {'elevation': 101.2,
#    'mindate': '1952-05-07',
#    'maxdate': '1967-12-31',
#    'latitude': 51.96667,
#    'name': 'WETHERSFIELD, UK',
#    'datacoverage': 0.9995,
#    'id': 'GHCND:UKW00035050',
#    'elevationUnit': 'METERS',
#    'longitude': 0.5},
#   {'elevation': 29.3,
#    'mindate': '1952-11-01',
#    'maxdate': '1967-12-31',
#    'latitude': 52.08333,
#    'name': 'WOODBRIDGE, UK',
#    'datacoverage': 0.8209,
#    'id': 'GHCND:UKW00035051',
#    'elevationUnit': 'METERS',
#    'longitude': 1.4},
#   {'elevation': 19.2,
#    'mindate': '1954-12-01',
#    'maxdate': '1958-08-05',
#    'latitude': 53.13333,
#    'name': 'EAST KIRKBY, UK',
#    'datacoverage': 0.4516,
#    'id': 'GHCND:UKW00035052',
#    'elevationUnit': 'METERS',
#    'longitude': 0},
#   {'elevation': 91.1,
#    'mindate': '1960-12-01',
#    'maxdate': '1964-06-29',
#    'latitude': 51.28333,
#    'name': 'WEST MALLING, UK',
#    'datacoverage': 1,
#    'id': 'GHCND:UKW00035054',
#    'elevationUnit': 'METERS',
#    'longitude': 0.4}]}

# %%
""" 
Choose "CET CENTRAL ENGLAND, UK" (first station): good data coverage and records begin in 1880. 
Check what temperature observations are available.
"""

make_request('datatypes', 
        {
            'datasetid' : 'GHCND',
            'stationid' : 'GHCND:UK000000000', # Station ID
            'datacategoryid' : 'TEMP' # Show temperature variables
        }).json()
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 2, 'limit': 25}},
#  'results': [{'mindate': '1763-01-01',
#    'maxdate': '2020-02-04',
#    'name': 'Maximum temperature',
#    'datacoverage': 1,
#    'id': 'TMAX'},
#   {'mindate': '1763-01-01',
#    'maxdate': '2020-02-04',
#    'name': 'Minimum temperature',
#    'datacoverage': 1,
#    'id': 'TMIN'}]}

# %%
""" 
Now let's pull the relevant data. We want TMAX and TMIN to calculate the mean. 
The API only allows one year of daily data to be grabbed at one go.
""" 

start = datetime.date(1881, 1, 1)
end = datetime.date(1882, 1, 1)

make_request('data', 
        {
            'datasetid' : 'GHCND',
            'stationid' : 'GHCND:UK000000000',
            'startdate' : start,
            'enddate' : end,
            'units' : 'metric', # Temperature units are degrees C
            'limit' : 1000 
        }).json()["results"]
# Out:
# [{'date': '1881-01-01T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 6.2},
#  {'date': '1881-01-01T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 1.4},
#  {'date': '1881-01-02T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 6.0},
#  {'date': '1881-01-02T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 3.8},
#  {'date': '1881-01-03T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 5.7},
#  {'date': '1881-01-03T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 4.4},
#  {'date': '1881-01-04T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 5.9},
#  {'date': '1881-01-04T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 3.7},
#  {'date': '1881-01-05T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 4.6},
#  {'date': '1881-01-05T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 2.9},
#  {'date': '1881-01-06T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 3.3},
#  {'date': '1881-01-06T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',I,E,',
#   'value': 1.4},
#  {'date': '1881-01-07T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',I,E,',
#   'value': 0.0},
#  {'date': '1881-01-07T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': -1.3},
#  {'date': '1881-01-08T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 1.1},
#  {'date': '1881-01-08T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': -2.9},
#  {'date': '1881-01-09T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 0.6},
#  {'date': '1881-01-09T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': -2.7},
#  {'date': '1881-01-10T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 0.5},
#  {'date': '1881-01-10T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': -3.0},
#  {'date': '1881-01-11T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 0.3},
#  {'date': '1881-01-11T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': -1.3},
#  {'date': '1881-01-12T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 0.2},
#  {'date': '1881-01-12T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': -6.3},
#  {'date': '1881-01-13T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': -4.3},
#  {'date': '1881-01-13T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': -6.0},
#  {'date': '1881-01-14T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': -2.6},
#  {'date': '1881-01-14T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': -9.8},
#  {'date': '1881-01-15T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': -2.5},
#  {'date': '1881-01-15T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': -11.7},
#  {'date': '1881-01-16T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': -1.2},
#  {'date': '1881-01-16T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': -12.8},
#  {'date': '1881-01-17T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value':
00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 5.8},
#  {'date': '1881-12-19T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 1.6},
#  {'date': '1881-12-20T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 6.5},
#  {'date': '1881-12-20T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 2.2},
#  {'date': '1881-12-21T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 3.7},
#  {'date': '1881-12-21T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 1.9},
#  {'date': '1881-12-22T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 3.4},
#  {'date': '1881-12-22T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': -0.8},
#  {'date': '1881-12-23T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 3.6},
#  {'date': '1881-12-23T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': -3.4},
#  {'date': '1881-12-24T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 7.3},
#  {'date': '1881-12-24T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': -4.6},
#  {'date': '1881-12-25T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 8.1},
#  {'date': '1881-12-25T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 1.1},
#  {'date': '1881-12-26T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 8.2},
#  {'date': '1881-12-26T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 4.3},
#  {'date': '1881-12-27T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 5.6},
#  {'date': '1881-12-27T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 3.2},
#  {'date': '1881-12-28T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 8.6},
#  {'date': '1881-12-28T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 2.0},
#  {'date': '1881-12-29T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 8.9},
#  {'date': '1881-12-29T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 2.6},
#  {'date': '1881-12-30T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 7.2},
#  {'date': '1881-12-30T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 5.5},
#  {'date': '1881-12-31T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 8.6},
#  {'date': '1881-12-31T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 3.2},
#  {'date': '1882-01-01T00:00:00',
#   'datatype': 'TMAX',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 10.0},
#  {'date': '1882-01-01T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:UK000000000',
#   'attributes': ',,E,',
#   'value': 3.8}]

# %%
"""
All looks good. Let's implement a loop that grabs the relevant data over all years of interest.
Again adapted from Stefanie Molin's code.
"""

start = 1881
end = 1890

results = []

while start < end:
    
    currentStart = datetime.date(start, 1, 1)
    currentEnd = datetime.date(start + 1, 1, 1)
    
    # Update the cell with status information
    display.clear_output(wait=True)
    display.display(f'Gathering data for {str(current)}')
    
    response = make_request('data', 
        {
            'datasetid' : 'GHCND', # Global Historical Climatology Network - Daily (GHCND) dataset
            'stationid' : 'GHCND:UK000000000', # Station ID
            'startdate' : currentStart,
            'enddate' : currentEnd,
            'units' : 'metric', # Temperature units are degrees C
            'limit' : 1000 # Return maximum allowed
        })

    if response.ok:
        # We extend the list instead of appending to avoid getting a nested list
        results.extend(response.json()['results'])

    # Update the current date to avoid an infinite loop
    start += 1
# Out:
# 'Gathering data for 1889-01-01'

# %%
# Convert to Pandas Dataframe
df = pd.DataFrame(results)
df.head()
# Out:
#   attributes datatype                 date            station  value
# 0       ,,E,     TMAX  1881-01-01T00:00:00  GHCND:UK000000000    6.2
# 1       ,,E,     TMIN  1881-01-01T00:00:00  GHCND:UK000000000    1.4
# 2       ,,E,     TMAX  1881-01-02T00:00:00  GHCND:UK000000000    6.0
# 3       ,,E,     TMIN  1881-01-02T00:00:00  GHCND:UK000000000    3.8
# 4       ,,E,     TMAX  1881-01-03T00:00:00  GHCND:UK000000000    5.7

# %%
# Quick plot
fig, ax = plt.subplots(1,1, figsize = (18,10))
df.query("datatype == 'TMAX'").plot(y = "value", ax = ax, color = "crimson", label = "Tmax")
df.query("datatype == 'TMIN'").plot(y = "value", ax = ax, color = "navy", label = "Tmin")
ax.set_xlabel("Days after 01/01/1881")
ax.set_ylabel("Temperature ($^\degree$C)")
plt.legend()
plt.show()
